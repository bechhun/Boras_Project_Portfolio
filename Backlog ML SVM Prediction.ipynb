# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import svm
from sklearn.linear_model import LogisticRegression

# %%
df = pd.read_csv(r'C:\Users\Bora\Management Of RBR\RBR Builds - Documents\RBR Analytics\ML Test\ML Logistic Regression.csv')
df
# Out:
#      Day Number  Immediate Processing- PSO   Qty Priority 1- eComplaints
# 0             1                           0                           11  \
# 1             2                           0                           54
# 2             3                           0                           54
# 3             4                           0                           40
# 4             5                           0                           40
# ..          ...                         ...                          ...
# 581           4                           0                           69
# 582           5                           0                           45
# 583           1                           0                           79
# 584           2                           0                           65
# 585           3                           1                            0
#
#      Qty Priority 2- Incompletes  Qty Priority 3- Injury Complaints
# ...

# %%
df.shape
# Out:
# (586, 20)

# %%
df.describe()
# Out:
#        Day Number  Immediate Processing- PSO   Qty Priority 1- eComplaints
# count  586.000000                  586.000000                   586.000000  \
# mean     3.011945                    0.510239                    45.069966
# std      1.401413                    1.014795                    38.006975
# min      1.000000                    0.000000                     0.000000
# 25%      2.000000                    0.000000                    14.000000
# 50%      3.000000                    0.000000                    39.000000
# 75%      4.000000                    1.000000                    69.000000
# max      5.000000                    8.000000                   182.000000
#
#        Qty Priority 2- Incompletes  Qty Priority 3- Injury Complaints
# count                   586.000000                         586.000000  \
# mean                     12.467577                          89.035836
# std                       9.863850                          40.918937
# ...

# %% [markdown]
# #### Backlog = 1 = >0  < 100
# #### Backlog = 2 = >100 < 500
# #### Backlog = 3 = > 500

# %%
df['Backlog'].mean()
# Out:
# 0.46757679180887374

# %%
df['Backlog'].value_counts()
# Out:
# Backlog
# 0    389
# 1    120
# 2     77
# Name: count, dtype: int64

# %%
df.groupby('Backlog').mean()
# Out:
#          Day Number  Immediate Processing- PSO   Qty Priority 1- eComplaints
# Backlog
# 0          2.994859                    0.437018                    39.079692  \
# 1          2.991667                    0.775000                    53.133333
# 2          3.129870                    0.467532                    62.766234
#
#          Qty Priority 2- Incompletes  Qty Priority 3- Injury Complaints
# Backlog
# 0                          13.701799                          85.526992  \
# 1                           9.975000                          92.583333
# 2                          10.116883                         101.233766
#
#          Qty Priority 4- Third Party  Qty Priority 5- Standard Complaints
# Backlog
# 0                           0.038560                             4.002571  \
# 1                           0.008333                             4.566667
# 2                           0.051948                             5.220779
#
# ...

# %%
X = df.drop(columns = ['NAM COFP', 'Backlog'])
Y = df['Backlog']

# %%
Scaler = StandardScaler()

# %%
Scaler.fit(X)
# Out:
# StandardScaler()

# %%
standardized_data= Scaler.transform(X)

# %%
standardized_data
# Out:
# array([[-1.43688095e+00, -5.03229390e-01, -8.97179351e-01, ...,
#         -8.21492697e-01, -5.27914911e-01, -2.91507139e+00],
#        [-7.22706023e-01, -5.03229390e-01,  2.35158505e-01, ...,
#         -8.11637879e-01, -1.17495515e+00, -8.54852853e-01],
#        [-8.53109977e-03, -5.03229390e-01,  2.35158505e-01, ...,
#         -3.41891553e-01, -9.38010835e-01, -1.84464282e-01],
#        ...,
#        [-1.43688095e+00, -5.03229390e-01,  8.93494467e-01, ...,
#          3.99094343e+00, -5.91707611e-01, -3.97026512e-01],
#        [-7.22706023e-01, -5.03229390e-01,  5.24826328e-01, ...,
#          4.21103437e+00,  8.29958257e-01,  7.71507700e-02],
#        [-8.53109977e-03,  4.83032893e-01, -1.18684717e+00, ...,
#          4.09934643e+00,  1.31237227e+01,  9.76452512e-01]])

# %%
X = standardized_data
Y = df['Backlog']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.2, stratify = Y, random_state = 2)

# %%
X.shape, X_train.shape, X_test.shape
# Out:
# ((586, 18), (468, 18), (118, 18))

# %%
classifier = svm.SVC(kernel = 'linear')

# %%
model = LogisticRegression

# %%
classifier.fit(X_train, Y_train)
# Out:
# SVC(kernel='linear')

# %%
X_train_prediction = classifier.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print('Accuracy score of the training data: ', training_data_accuracy)
# Out:
# Accuracy score of the training data:  0.9829059829059829

# %%
X_test_prediction = classifier.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print('Accuracy score of the test data: ', test_data_accuracy)
# Out:
# Accuracy score of the test data:  0.940677966101695

# %%
input_data = (1,0,89,2,67,0,4,40,5,25,5,237,710,115,6,710,115,237)

input_data_as_numpy_array = np.asarray(input_data)

input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

std_data = Scaler.transform(input_data_reshaped)
print(std_data)

prediction = classifier.predict(std_data)

print(prediction)

if (prediction[0] == 0):
    print('There will be a backlog of between 0 to 100')
if    (prediction[0] == 1):
    print('There will be a backlog of between 100 to 500')
else:
    print('There will be a backlog of over 500')
# Out:
# [[-1.43688095 -0.50322939  1.15682885 -1.06211267 -0.53898424 -0.15807437
#   -0.05040769 -0.11101154  0.08354712  0.49875998 -0.19595049  0.20897896
#    0.97271869 -1.00926932 -0.42651558  0.89981552 -1.17495515 -0.0700077 ]]
# [1]
# There will be a backlog of between 100 to 500
# C:\Users\Bora\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
